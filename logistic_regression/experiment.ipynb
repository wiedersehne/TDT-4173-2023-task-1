# %% [markdown]
# # Logistic Regression
#
# For this problem, you will be implementing a Logistic Regression model for binary classification (yes-or-no like predictions). This is a simple model with restricted application areas, but it is very useful when applied to appropriate problems. Moreover, for those of you interested in Deep Learning, many of the concepts covered here are fundamental to how most neural networks as built and optimized.
#
# You should begin by implementing a standard form of logistic regression. That is, we want to predict a target variable $y \in \{0, 1\}$ given observed feature variables $x \in \mathbb{R}^n$, and their relationship is modeled as:
#
# - prediction $ = \hat{y} = h_\theta(x) = \sigma(\theta^T x) \in (0, 1)$, where:
#     - $h_\theta$ is your Logistic Regression model
#     - $\theta \in \mathbb{R}^n$ is the parameters of the model
#     - $\sigma(z) = \frac{1}{1 + e^{-z}}$ is the logistic function (`sigmoid` in the provided code)
#
# The parameters $\theta$ should be optimized with gradient descent on a loss derived from maximum likelihood estimation under the assumption that $P(y | x, \theta)$ is Bernoulli distributed.
# Please refer to [Andrew Ng's lecture notes on supervised learning](http://cs229.stanford.edu/notes2020spring/cs229-notes1.pdf) for more details. The most salient information for this problem can be found in Section 5, but we recommend that you read through all of it.
#
# We have provided some skeleton code for the classifier, along with a couple of utility functions in the [logistic_regression.py](./logistic_regression.py) module. Please fill out the functions marked with `TODO` and feel free to add extra constructor arguments as you see fit (just make sure the default constructor solves the first dataset).

# %%
# %load_ext autoreload

# %% [markdown]
# We begin by loading necessary packages. Below follows a short description of the imported modules:
#
# - `numpy` is the defacto python package for numerical calculation. Most other numerical libraries (including pandas) is based on numpy.
# - `pandas` is a widely used package for manipulating (mostly) tabular data
# - `matplotlib` is the most used plotting library for python
# - `seaborn` contains several convience functions for matplotlib and integrates very well with pandas
# - `logistic_regression` refers to the module in this folder that should be further implemented by you.
#
# Note: The `%autoreload` statement is an [IPython magic command](https://ipython.readthedocs.io/en/stable/interactive/magics.html) that automatically reloads the newest version of all imported modules within the cell. This means that you can edit the `logistic_regression.py` file and just rerun this cell to get the updated version.

# %%
# %autoreload 

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import logistic_regression as lr   # <-- Your implementation

sns.set_style('darkgrid') # Seaborn plotting style

# %% [markdown]
# ## [1] First Dataset
#
# The first dataset is a simple problem that can be used to debug your algorithm. The objective is to predict whether the dependent variable ($y$) should be equal to 1 or 0 based on two independent variables ($x_0$ and $x_1$).
#
# ### [1.1] Load Data
#
# We begin by loading data from the .csv file located in the same folder as this notebook.

# %%
data_1 = pd.read_csv('data_1.csv')
data_1.head()
# Out:
#          x0        x1    y
# 0  0.167745  0.025549  0.0
# 1  0.916503  0.744718  1.0
# 2  0.056172  0.586527  0.0
# 3  0.453699  0.495267  1.0
# 4  0.621778  0.437974  1.0

# %% [markdown]
# ### [1.2] Visualize
#
# Since the feature-space is continuous and 2-dimensional, it lends itself nicely to visualization with a scatter plot.

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(x='x0', y='x1', hue='y', data=data_1);

# %% [markdown]
# ### [1.3] Train and Evaluate
#
# Next we fit and evaluate a Logistic Regression classifier over the dataset. We first partition the data into the dependent (`y`) and independent (`X`) variables. We then initialize a Logistic Regression classifier and fit it to all the data. Finally, we evaluate the model over the same data by calculating _accuracy_ and (binary) _cross entropy_.
#
# - The accuracy is given by the fraction of correctly classified samples. Since the Logistic Regression classifier outputs "soft" predictions ($\hat{y} \in (0, 1)$), we threshold the predictions so that $\hat{y} \geq 0.5$ is considered a $1$ and $\hat{y} < 0.5$ is considered a $0$.
#
# - The [cross entropy](https://en.wikipedia.org/wiki/Cross_entropy) measures the dissimilarity between the distributions of the true labels ($y$) and the "label-probablities" ($\hat{y}$) predicted by your model. It is subject to minimization and (hint) _highly_ related to your maximal likelihood objective.
#
# Note that `.fit` and `.predict` will crash until you implement these two methods in [logistic_regression.py](./logistic_regression.py).
#
# Assuming a standard implementation of logistic regression with batch gradient descent, you should expect to get an accuracy of at least 90%.

# %%
# Partition data into independent (feature) and depended (target) variables
X = data_1[['x0', 'x1']]
y = data_1['y']

# Create and train model.
model_1 = lr.LogisticRegression() # <-- Should work with default constructor  
model_1.fit(X, y)

# Calculate accuracy and cross entropy for (insample) predictions 
y_pred = model_1.predict(X)
print(f'Accuracy: {lr.binary_accuracy(y_true=y, y_pred=y_pred, threshold=0.5) :.3f}')
print(f'Cross Entropy: {lr.binary_cross_entropy(y_true=y, y_pred=y_pred) :.3f}')
# Out:
# cost after 0 iterations of gradient descent is: 0.6522613928999142
# cost after 1000 iterations of gradient descent is: 0.1293138722613226
# cost after 2000 iterations of gradient descent is: 0.11368146229744483
# cost after 3000 iterations of gradient descent is: 0.1074068332936922
# cost after 4000 iterations of gradient descent is: 0.1040186822048093
# cost after 5000 iterations of gradient descent is: 0.1019278051049202
# cost after 6000 iterations of gradient descent is: 0.10053418802979763
# cost after 7000 iterations of gradient descent is: 0.09955736144141175
# cost after 8000 iterations of gradient descent is: 0.09884792473958305
# cost after 9000 iterations of gradient descent is: 0.09831890567007681
# Accuracy: 0.980
# Cross Entropy: 0.098

# %% [markdown]
# ### [1.4] Visualize Decision Boundary
#
# Logistic Regression does not make hard classification decisions. Instead, it attempts to model the probability of a datapoint belonging to the 1-class after conditioning on the available features ($x_0, x_1$ here). The modeled probability of the 0-class can be obtained by negating and adding one.
#
# We can visualize the modeled probabilities across the entire input space. In the cell below, we rasterize the model's prediction over a grid that covers approximately the same area as the data used to train it. Red regions correspond to high modeled probability for the 1-class whereas blue correspond to high modeled probability for the 0-class. Does the decisions of your model line up well with the provided data? What happens if you train it for longer?

# %%
# Rasterize the model's predictions over a grid
xx0, xx1 = np.meshgrid(np.linspace(-0.1, 1.1, 100), np.linspace(-0.1, 1.1, 100))
yy = model_1.predict(np.stack([xx0, xx1], axis=-1).reshape(-1, 2)).reshape(xx0.shape)

# Plot prediction countours along with datapoints
_, ax = plt.subplots(figsize=(4, 4), dpi=100)
levels = [0, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 1.0]
contours = ax.contourf(xx0, xx1, yy, levels=levels, alpha=0.4, cmap='RdBu_r', vmin=0, vmax=1)
legends = [plt.Rectangle((0,0),1,1,fc = pc.get_facecolor()[0]) for pc in contours.collections]
labels = [f'{a :.2f} - {b :.2f}' for a,b in zip(levels, levels[1:])]
sns.scatterplot(x='x0', y='x1', hue='y', ax=ax, data=data_1)
ax.legend(legends, labels, bbox_to_anchor=(1,1));

# %% [markdown]
# ## [2] Second Dataset
#
# The second dataset is superficially similar to the first one. The objective is still to predict whether the dependent variable ($y$) should be equal to 1 or 0 based on two independent variables ($x_0$ and $x_1$). However, it is designed to be a bit more challenging. You might want to explore it beyond what is provided in the cells below.
#
# ### [2.1] Load Data
#
# This dataset can also be found in a .csv file in the same folder as this notebook.

# %%
# Load second dataset and partition into train/test split
data_2 = pd.read_csv('data_2.csv')
data_2.head()
# Out:
#          x0        x1    y  split
# 0  0.872494  0.739252  1.0  train
# 1  0.650888  0.378137  0.0  train
# 2  0.228505  0.493694  0.0  train
# 3  0.037880  0.756215  1.0  train
# 4  0.542346  0.159417  1.0  train

# %% [markdown]
# ### [2.2] Split Data
#
# The dataset is partitioned into two groups:
#
# - `train` contains 500 samples that you should use to fit the model
# - `test` contains another 500 samples that should only be used to check that your solution generalizes well to novel data

# %%
data_2_train = data_2.query('split == "train"')
data_2_test = data_2.query('split == "test"')

# Partition data into independent (features) and depended (targets) variables
X_train, y_train = data_2_train[['x0', 'x1']], data_2_train['y']
X_test, y_test = data_2_test[['x0', 'x1']], data_2_test['y']

# %% [markdown]
# ### [2.3] Exploratory Data Analysis
# As we are working with logistic regression, it's a good idea to make a scatterplot in order to check the destribution of our data points. This is easy as we have a 2D feature space

# %%
sns.scatterplot(x = "x0", y = "x1", hue = "y", data = data_2_train)
# Out:
# <AxesSubplot:xlabel='x0', ylabel='x1'>

# %% [markdown]
# It's evident that the data is not linearly seperable. We will not be able to find a suitable linear decision boundry which can seperate our data. We therefore need to feature engineer, in order to transform our feature space (by transforming from cartisian to polar cordiantes or adding additional features such as combinations of our current features). We are then adding non-linearities to through our features.
# Keep in mind that this indtoduces a bias / varience tradeoff as we introduce a more complex feature space.
# A validation set should be used to tune this tradeoff.

# %% [markdown]
# ## Feature engineer test
# Different datasets will be made with different feature combinations and the accuracy (and underfitting / overfitting) will be checked for each dataset. Keep in mind that using the test set for cross-validation is a major nono in machine learning!
#
# Heatmaps can be an advantage here to check feature to lable correlations.

# %%
#Adding a x_1^2 feature
x1_squared_vals =  data_2["x1"] * data_2["x1"]
data_2.insert(2, "x1^2", x1_squared_vals)
data_2.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11696\3320368251.py in ?()
#       1 #Adding a x_1^2 feature
#       2 x1_squared_vals =  data_2["x1"] * data_2["x1"]
#       3 data_2_x1_squared = data_2
# ----> 4 data_2_x1_squared.insert(2, "x1^2", x1_squared_vals)
#       5 data_2.head()
#
# c:\Users\Shahl\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    4768                 "'self.flags.allows_duplicate_labels' is False."
#    4769             )
#    4770         if not allow_duplicates and column in self.columns:
#    4771             # Should this be a different kind of error??
# -> 4772             raise ValueError(f"cannot insert {column}, already exists")
#    4773         if not isinstance(loc, int):
#    4774             raise TypeError("loc must be int")
#    4775
#
# ValueError: cannot insert x1^2, already exists

# %%
#Lets resplit into a train / test set
data_x1_squared_train = data_2.query('split == "train"')
data_x1_squared_test = data_2.query('split == "test"')

# Partition data into independent (features) and depended (targets) variables
X_train_x1_squared, y_train = data_x1_squared_train[['x0', 'x1', "x1^2"]], data_x1_squared_train['y']
X_test_x1_squared, y_test = data_x1_squared_test[['x0', 'x1', "x1^2"]], data_x1_squared_test['y']

# %%
data_2 = data_2.drop(columns=["x1^2"])
x1_mult_x2_vals =  data_2["x0"] * data_2["x1"]
data_2.insert(2, "x1*x2", x1_mult_x2_vals)
data_2.head()
# Out:
#          x0        x1     x1*x2    y  split
# 0  0.872494  0.739252  0.644993  1.0  train
# 1  0.650888  0.378137  0.246125  0.0  train
# 2  0.228505  0.493694  0.112812  0.0  train
# 3  0.037880  0.756215  0.028645  1.0  train
# 4  0.542346  0.159417  0.086459  1.0  train

# %%
#Lets resplit into a train / test set
data_x1_mult_x0_train = data_2.query('split == "train"')
data_x1_mult_x0_test = data_2.query('split == "test"')

# Partition data into independent (features) and depended (targets) variables
X_train_x1_mult_x0, y_train = data_x1_mult_x0_train[['x0', 'x1', "x1*x2"]], data_x1_mult_x0_train['y']
X_test_x1_mult_x0, y_test = data_x1_mult_x0_test[['x0', 'x1', "x1*x2"]], data_x1_mult_x0_test['y']

# %%
data_2.insert(2, "x1^2", x1_squared_vals)
data_2.head()
# Out:
#          x0        x1      x1^2     x1*x2    y  split
# 0  0.872494  0.739252  0.546494  0.644993  1.0  train
# 1  0.650888  0.378137  0.142988  0.246125  0.0  train
# 2  0.228505  0.493694  0.243734  0.112812  0.0  train
# 3  0.037880  0.756215  0.571861  0.028645  1.0  train
# 4  0.542346  0.159417  0.025414  0.086459  1.0  train

# %%
#Lets resplit into a train / test set
data_x1_squared_x1_mult_x2_train = data_2.query('split == "train"')
data_x1_squared_x1_mult_x2_test = data_2.query('split == "test"')

# Partition data into independent (features) and depended (targets) variables
X_train_x1_squared_x1_mult_x2, y_train = data_x1_squared_x1_mult_x2_train[['x0', 'x1', "x1*x2", "x1^2"]], data_x1_squared_x1_mult_x2_train['y']
X_test_x1_squared_x1_mult_x2, y_test = data_x1_squared_x1_mult_x2_test[['x0', 'x1', "x1*x2", "x1^2"]], data_x1_squared_x1_mult_x2_test['y']

# %%
data_2 = data_2.drop(columns=["x1*x2"])
x0_squared = data_2["x0"] * data_2["x0"]
data_2.insert(2, "x0^2", x0_squared)
data_2.head()
# Out:
#          x0        x1      x0^2      x1^2    y  split
# 0  0.872494  0.739252  0.761246  0.546494  1.0  train
# 1  0.650888  0.378137  0.423655  0.142988  0.0  train
# 2  0.228505  0.493694  0.052215  0.243734  0.0  train
# 3  0.037880  0.756215  0.001435  0.571861  1.0  train
# 4  0.542346  0.159417  0.294139  0.025414  1.0  train

# %%
#Lets resplit into a train / test set
data_squared_all = data_2.query('split == "train"')
data_squared_all_test = data_2.query('split == "test"')

# Partition data into independent (features) and depended (targets) variables
X_train_squared_all, y_train = data_squared_all[['x0', 'x1', "x0^2", "x1^2"]], data_squared_all['y']
X_test_squared_all, y_test = data_squared_all_test[['x0', 'x1', "x0^2", "x1^2"]], data_squared_all_test['y']

# %% [markdown]
# ### [2.4] Fit and Evaluate Model
#
# You may notice that the algorithm that worked pretty well on the first dataset comes up a bit short here. Feel free to add extra functionality to it and/or the data preprocessing pipeline that might improve performance. As a debugging reference; it is possible to obtain accuracies over 80%, both on train and the test set.

# %%
#initialize the model
model_2 = lr.LogisticRegression()  # <--- Feel free to add hyperparameters

# Calculate accuracy and cross entropy for insample predictions 
print("===================NO FEATURE ENGINEERING===============")
model_2.fit(X_train, y_train)
y_pred_train = model_2.predict(X_train)
print('Train')
print(f'Accuracy: {lr.binary_accuracy(y_true=y_train, y_pred=y_pred_train, threshold=0.5) :.3f}')
print(f'Cross Entropy:  {lr.binary_cross_entropy(y_true=y_train, y_pred=y_pred_train) :.3f}')

# Calculate accuracy and cross entropy for out-of-sample predictions
y_pred_test = model_2.predict(X_test)
print('\nTest')
print(f'Accuracy: {lr.binary_accuracy(y_true=y_test, y_pred=y_pred_test, threshold=0.5) :.3f}')
print(f'Cross Entropy:  {lr.binary_cross_entropy(y_true=y_test, y_pred=y_pred_test) :.3f}')


# Calculate accuracy and cross entropy for insample predictions with x1^2
print("===================x1^2 FEATURE================")
model_2.fit(X_train_x1_squared, y_train)
y_pred_train = model_2.predict(X_train_x1_squared)
print('Train')
print(f'Accuracy: {lr.binary_accuracy(y_true=y_train, y_pred=y_pred_train, threshold=0.5) :.3f}')
print(f'Cross Entropy:  {lr.binary_cross_entropy(y_true=y_train, y_pred=y_pred_train) :.3f}')

# Calculate accuracy and cross entropy for out-of-sample predictions
y_pred_test = model_2.predict(X_test_x1_squared)
print('\nTest')
print(f'Accuracy: {lr.binary_accuracy(y_true=y_test, y_pred=y_pred_test, threshold=0.5) :.3f}')
print(f'Cross Entropy:  {lr.binary_cross_entropy(y_true=y_test, y_pred=y_pred_test) :.3f}')


print("===================x1 mult x0 FEATURE================")
model_2.fit(X_train_x1_mult_x0, y_train)
y_pred_train = model_2.predict(X_train_x1_mult_x0)
print('Train')
print(f'Accuracy: {lr.binary_accuracy(y_true=y_train, y_pred=y_pred_train, threshold=0.5) :.3f}')
print(f'Cross Entropy:  {lr.binary_cross_entropy(y_true=y_train, y_pred=y_pred_train) :.3f}')

# Calculate accuracy and cross entropy for out-of-sample predictions
y_pred_test = model_2.predict(X_test_x1_mult_x0)
print('\nTest')
print(f'Accuracy: {lr.binary_accuracy(y_true=y_test, y_pred=y_pred_test, threshold=0.5) :.3f}')
print(f'Cross Entropy:  {lr.binary_cross_entropy(y_true=y_test, y_pred=y_pred_test) :.3f}')


print("===================x1*x0 and x1^2  FEATURE================")
model_2.fit(X_train_x1_squared_x1_mult_x2, y_train)
y_pred_train = model_2.predict(X_train_x1_squared_x1_mult_x2)
print('Train')
print(f'Accuracy: {lr.binary_accuracy(y_true=y_train, y_pred=y_pred_train, threshold=0.5) :.3f}')
print(f'Cross Entropy:  {lr.binary_cross_entropy(y_true=y_train, y_pred=y_pred_train) :.3f}')

# Calculate accuracy and cross entropy for out-of-sample predictions
y_pred_test = model_2.predict(X_test_x1_squared_x1_mult_x2)
print('\nTest')
print(f'Accuracy: {lr.binary_accuracy(y_true=y_test, y_pred=y_pred_test, threshold=0.5) :.3f}')
print(f'Cross Entropy:  {lr.binary_cross_entropy(y_true=y_test, y_pred=y_pred_test) :.3f}')


print("===================x1 and x0 squared FEATURES================")
model_2.fit(X_train_squared_all, y_train)
y_pred_train = model_2.predict(X_train_squared_all)
print('Train')
print(f'Accuracy: {lr.binary_accuracy(y_true=y_train, y_pred=y_pred_train, threshold=0.5) :.3f}')
print(f'Cross Entropy:  {lr.binary_cross_entropy(y_true=y_train, y_pred=y_pred_train) :.3f}')

# Calculate accuracy and cross entropy for out-of-sample predictions
y_pred_test = model_2.predict(X_test_squared_all)
print('\nTest')
print(f'Accuracy: {lr.binary_accuracy(y_true=y_test, y_pred=y_pred_test, threshold=0.5) :.3f}')
print(f'Cross Entropy:  {lr.binary_cross_entropy(y_true=y_test, y_pred=y_pred_test) :.3f}')
# Out:
# ===================NO FEATURE ENGINEERING===============
# cost after 0 iterations of gradient descent is: 0.7878805135076242
# cost after 1000 iterations of gradient descent is: 0.6701410411564956
# cost after 2000 iterations of gradient descent is: 0.6701410411564782
# cost after 3000 iterations of gradient descent is: 0.6701410411564782
# cost after 4000 iterations of gradient descent is: 0.6701410411564782
# cost after 5000 iterations of gradient descent is: 0.6701410411564782
# cost after 6000 iterations of gradient descent is: 0.6701410411564782
# cost after 7000 iterations of gradient descent is: 0.6701410411564782
# cost after 8000 iterations of gradient descent is: 0.6701410411564782
# cost after 9000 iterations of gradient descent is: 0.6701410411564782
# Train
# Accuracy: 0.604
# Cross Entropy:  0.670
#
# Test
# Accuracy: 0.616
# Cross Entropy:  0.666
# ===================x1^2 FEATURE================
# cost after 0 iterations of gradient descent is: 1.0061998209431646
# cost after 1000 iterations of gradient descent is: 0.4602576963739548
# cost after 2000 iterations of gradient descent is: 0.38209703129531103
# cost after 3000 iterations of gradient descent is: 0.3411325888564163
# cost after 4000 iterations of gradient descent is: 0.31537165945387163
# cost after 5000 iterations of gradient descent is: 0.2973744259246435
# cost after 6000 iterations of gradient descent is: 0.28393105547023073
# cost after 7000 iterations of gradient descent is: 0.2734178924875964
# cost after 8000 iterations of gradient descent is: 0.264918244437106
# cost after 9000 iterations of gradient descent is: 0.25787150023518257
# Train
# Accuracy: 0.928
# Cross Entropy:  0.252
#
# Test
# Accuracy: 0.918
# Cross Entropy:  0.274
# ===================x1 mult x0 FEATURE================
# cost after 0 iterations of gradient descent is: 0.6923851208305826
# cost after 1000 iterations of gradient descent is: 0.6683053432558147
# cost after 2000 iterations of gradient descent is: 0.6683022351691165
# cost after 3000 iterations of gradient descent is: 0.6683017997081308
# cost after 4000 iterations of gradient descent is: 0.6683017386696339
# cost after 5000 iterations of gradient descent is: 0.6683017301123932
# cost after 6000 iterations of gradient descent is: 0.6683017289126396
# cost after 7000 iterations of gradient descent is: 0.6683017287444261
# cost after 8000 iterations of gradient descent is: 0.6683017287208413
# cost after 9000 iterations of gradient descent is: 0.6683017287175343
# Train
# Accuracy: 0.604
# Cross Entropy:  0.668
#
# Test
# Accuracy: 0.616
# Cross Entropy:  0.669
# ===================x1*x0 and x1^2  FEATURE================
# cost after 0 iterations of gradient descent is: 0.7474556924186148
# cost after 1000 iterations of gradient descent is: 0.4506487557216318
# cost after 2000 iterations of gradient descent is: 0.3769255073327425
# cost after 3000 iterations of gradient descent is: 0.3379118575125048
# cost after 4000 iterations of gradient descent is: 0.3130630289443245
# cost after 5000 iterations of gradient descent is: 0.29552753422658384
# cost after 6000 iterations of gradient descent is: 0.28232655829658304
# cost after 7000 iterations of gradient descent is: 0.27193937767051757
# cost after 8000 iterations of gradient descent is: 0.26350022218549723
# cost after 9000 iterations of gradient descent is: 0.25647571194384616
# Train
# Accuracy: 0.940
# Cross Entropy:  0.251
#
# Test
# Accuracy: 0.912
# Cross Entropy:  0.272
# ===================x1 and x0 squared FEATURES================
# cost after 0 iterations of gradient descent is: 1.2287415393896446
# cost after 1000 iterations of gradient descent is: 0.4454693828509668
# cost after 2000 iterations of gradient descent is: 0.3582850592677089
# cost after 3000 iterations of gradient descent is: 0.3116582634880461
# cost after 4000 iterations of gradient descent is: 0.2818660232884339
# cost after 5000 iterations of gradient descent is: 0.26075261773128555
# cost after 6000 iterations of gradient descent is: 0.24476223262070415
# cost after 7000 iterations of gradient descent is: 0.23208438981194857
# cost after 8000 iterations of gradient descent is: 0.22169264065530087
# cost after 9000 iterations of gradient descent is: 0.2129574418884466
# Train
# Accuracy: 0.958
# Cross Entropy:  0.205
#
# Test
# Accuracy: 0.938
# Cross Entropy:  0.213

# %% [markdown]
# ## [3] Further Steps (optional)
#
# If you're done with the assignment but want to some more challenges; consider the following:
#
# - Try a different objective function (e.g. [hinge-loss](https://en.wikipedia.org/wiki/Hinge_loss)). How does this affect the classifier?
# - Try a more sophisticated stopping criterion than a fixed number of epochs
# - Try a different optimization algorithm than simple gradient descent, for instance:
#     - The [ADAM](https://optimization.cbe.cornell.edu/index.php?title=Adam) optimizer is a variation of gradient descent that is quite popular in deep learning.
#     - The quasi-newton method [BGFS](https://optimization.cbe.cornell.edu/index.php?title=Quasi-Newton_methods#BFGS_method), which typically converge much faster
# - Try to generalize your classifier to a [Multilayer Perceptron](https://en.wikipedia.org/wiki/Multilayer_perceptron) neural network classifier.
